# %%
from smolagents import CodeAgent, LiteLLMModel
from smolagents import tool
from smolagents.agents import ToolCallingAgent
from smolagents import DuckDuckGoSearchTool

# %%
# load ../llama-b7207-bin-win-cpu-x64/qwen7b-chat.gguf model
model = LiteLLMModel(model_id="huggingface/qwen2.5-coder-7b-instruct-q4_k_m",model_path="../llama-b7208-bin-win-cpu-x64/qwen2.5-coder-7b-instruct-q4_k_m.gguf", api_key=None, api_base="http://127.0.0.1:8080")

# %%
agent = CodeAgent(tools=[], model=model, add_base_tools=True, additional_authorized_imports=["numpy", "pandas",'sys','requests',"matplotlib",'matplotlib.pyplot'])

# %%
agent.run("Solve the quadratic equation ax^2 + bx + c = 0 for a=1, b=-3, c=2")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Solve the quadratic equation ax^2 + bx + c = 0 for a=1, b=-3, c=2                                               │
# │                                                                                                                 │
# ╰─ LiteLLMModel - huggingface/qwen2.5-coder-7b-instruct-q4_k_m ───────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import math
#
#   a = 1
#   b = -3
#   c = 2
#
#   # Calculate the discriminant
#   discriminant = b**2 - 4*a*c
#   print(f"The discriminant is {discriminant}.")
#
# ...

# %%
agent.run("Calculate the integral of x^2 from 0 to 10 and plot the function")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Calculate the integral of x^2 from 0 to 10 and plot the function                                                │
# │                                                                                                                 │
# ╰─ LiteLLMModel - huggingface/qwen2.5-coder-7b-instruct-q4_k_m ───────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import sympy as sp
#   import matplotlib.pyplot as plt
#
#   # Define the variable
#   x = sp.symbols('x')
#
#   # Define the function
#   f = x**2
#
# ...
